# %% [markdown]
# # CNN 10 Folds Cross Validation

# %% [markdown]
# From our paper on "Explainable Prediction of Acute Myocardial Infarction using Machine Learning and Shapley Values"

# %%
# Import libraries
import pandas as pd
import numpy as np
import pylab as plt
from keras import optimizers, losses, activations, models, regularizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, Flatten, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate
from keras.utils import to_categorical
from keras.models import load_model, Sequential
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import train_test_split
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
# Out:
# Using TensorFlow backend.

# %%
def make_model(learning_rate=0.001):
    # number of categories in our problem
    opt = optimizers.Adam(learning_rate)
    model = Sequential()
    # shape of input
    model.add (Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid", input_shape=(11,1)))
    model.add (Dropout(rate=0.1))
    model.add (Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid"))
    model.add (Dropout(rate=0.1))
    model.add (Convolution1D(64, kernel_size=3, activation=activations.relu, padding="valid"))
    model.add (Dropout(rate=0.1))
    model.add (Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid"))
    model.add (GlobalMaxPool1D())
    model.add (Dropout(rate=0.1))
    model.add (Dense(64, activation=activations.relu, name="dense_1", kernel_regularizer=regularizers.l2(l=0.1)))
    model.add (Dense(16, activation=activations.relu, name="dense_2", kernel_regularizer=regularizers.l2(l=0.1)))
    model.add (Dense(2, activation=activations.softmax, name="dense_3_ecg_view"))
    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=['acc'])
    return model

# %%
file_path = "baseline_cnn_ecgview_kfolds.h5"

# Checkpoint the model's weight based on the accuracy of the model
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# Set early stopping based on accuracy. It stops after 10 consecutive epochs of no accuracy improvement.
early = EarlyStopping(monitor="val_acc", mode="max", patience=10, verbose=1)

# Reduce learning rate based on accuracy. It reduces the rate after 7 consecutive epochs of no accuracy improvement.
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=7, verbose=2)

callbacks_list = [checkpoint, early, redonplat]

# %%
# Load array
train = loadtxt('train.csv', delimiter=',')
test = loadtxt('test.csv', delimiter=',')

# Split array
train_x = train[:,:11]
test_x = test[:,:11]
train_y = train[:,11]
test_y = test[:,11]

x_re = np.vstack((train_x, test_x))
y_re = np.vstack((train_y[:, None], test_y[:, None]))

# %%
# 10-fold cross validation on the test data 
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

X_re = np.reshape(x_re, (x_re.shape[0], x_re.shape[1], 1))

kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []

for train, test in kfold.split(X_re, y_re):
    model = make_model(learning_rate = 0.001)
    # Fit the model
    model.fit(X_re[train],to_categorical(y_re[train]), epochs=1000, verbose=0, callbacks=callbacks_list, validation_split=0.1)
    # Evaluate the model
    scores = model.evaluate(X_re[test], to_categorical(y_re[test]), verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# Epoch 00001: val_acc improved from -inf to 0.61715, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00002: val_acc did not improve from 0.61715
#
# Epoch 00003: val_acc improved from 0.61715 to 0.66832, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00004: val_acc did not improve from 0.66832
#
# Epoch 00005: val_acc did not improve from 0.66832
#
# Epoch 00006: val_acc did not improve from 0.66832
#
# Epoch 00007: val_acc improved from 0.66832 to 0.68849, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00008: val_acc improved from 0.68849 to 0.73058, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00009: val_acc did not improve from 0.73058
#
# Epoch 00010: val_acc did not improve from 0.73058
#
# Epoch 00011: val_acc improved from 0.73058 to 0.80721, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00012: val_acc did not improve from 0.80721
#
# Epoch 00013: val_acc did not improve from 0.80721
#
# Epoch 00014: val_acc did not improve from 0.80721
#
# Epoch 00015: val_acc did not improve from 0.80721
#
# Epoch 00016: val_acc did not improve from 0.80721
#
# Epoch 00017: val_acc did not improve from 0.80721
#
# Epoch 00018: val_acc did not improve from 0.80721
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_acc did not improve from 0.80721
#
# Epoch 00020: val_acc did not improve from 0.80721
#
# Epoch 00021: val_acc did not improve from 0.80721
# Epoch 00021: early stopping
# acc: 87.41%
#
# Epoch 00001: val_acc did not improve from 0.80721
#
# Epoch 00002: val_acc did not improve from 0.80721
#
# Epoch 00003: val_acc did not improve from 0.80721
#
# Epoch 00004: val_acc did not improve from 0.80721
#
# Epoch 00005: val_acc did not improve from 0.80721
#
# Epoch 00006: val_acc did not improve from 0.80721
#
# Epoch 00007: val_acc did not improve from 0.80721
#
# Epoch 00008: val_acc did not improve from 0.80721
#
# Epoch 00009: val_acc did not improve from 0.80721
#
# Epoch 00010: val_acc did not improve from 0.80721
#
# Epoch 00011: val_acc did not improve from 0.80721
#
# Epoch 00012: val_acc did not improve from 0.80721
#
# Epoch 00013: val_acc did not improve from 0.80721
#
# Epoch 00014: val_acc did not improve from 0.80721
#
# Epoch 00015: val_acc improved from 0.80721 to 0.81106, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00016: val_acc did not improve from 0.81106
#
# Epoch 00017: val_acc did not improve from 0.81106
#
# Epoch 00018: val_acc improved from 0.81106 to 0.81549, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00019: val_acc did not improve from 0.81549
#
# Epoch 00020: val_acc did not improve from 0.81549
#
# Epoch 00021: val_acc improved from 0.81549 to 0.82074, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00022: val_acc did not improve from 0.82074
#
# Epoch 00023: val_acc improved from 0.82074 to 0.82711, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00024: val_acc did not improve from 0.82711
#
# Epoch 00025: val_acc did not improve from 0.82711
#
# Epoch 00026: val_acc did not improve from 0.82711
#
# Epoch 00027: val_acc did not improve from 0.82711
#
# Epoch 00028: val_acc improved from 0.82711 to 0.85812, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00029: val_acc did not improve from 0.85812
#
# Epoch 00030: val_acc did not improve from 0.85812
#
# Epoch 00031: val_acc did not improve from 0.85812
#
# Epoch 00032: val_acc did not improve from 0.85812
#
# Epoch 00033: val_acc did not improve from 0.85812
#
# Epoch 00034: val_acc did not improve from 0.85812
#
# Epoch 00035: val_acc did not improve from 0.85812
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00036: val_acc did not improve from 0.85812
#
# Epoch 00037: val_acc did not improve from 0.85812
#
# Epoch 00038: val_acc did not improve from 0.85812
# Epoch 00038: early stopping
# acc: 88.75%
#
# Epoch 00001: val_acc did not improve from 0.85812
#
# Epoch 00002: val_acc did not improve from 0.85812
#
# Epoch 00003: val_acc did not improve from 0.85812
#
# Epoch 00004: val_acc did not improve from 0.85812
#
# Epoch 00005: val_acc did not improve from 0.85812
#
# Epoch 00006: val_acc did not improve from 0.85812
#
# Epoch 00007: val_acc did not improve from 0.85812
#
# Epoch 00008: val_acc did not improve from 0.85812
#
# Epoch 00009: val_acc did not improve from 0.85812
#
# Epoch 00010: val_acc did not improve from 0.85812
#
# Epoch 00011: val_acc did not improve from 0.85812
#
# Epoch 00012: val_acc did not improve from 0.85812
#
# Epoch 00013: val_acc did not improve from 0.85812
#
# Epoch 00014: val_acc did not improve from 0.85812
#
# Epoch 00015: val_acc did not improve from 0.85812
#
# Epoch 00016: val_acc did not improve from 0.85812
#
# Epoch 00017: val_acc did not improve from 0.85812
#
# Epoch 00018: val_acc did not improve from 0.85812
#
# Epoch 00019: val_acc did not improve from 0.85812
#
# Epoch 00020: val_acc did not improve from 0.85812
#
# Epoch 00021: val_acc improved from 0.85812 to 0.86485, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00022: val_acc did not improve from 0.86485
#
# Epoch 00023: val_acc did not improve from 0.86485
#
# Epoch 00024: val_acc improved from 0.86485 to 0.86745, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00030: val_acc did not improve from 0.86745
#
# Epoch 00031: val_acc did not improve from 0.86745
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00032: val_acc did not improve from 0.86745
#
# Epoch 00033: val_acc did not improve from 0.86745
#
# Epoch 00034: val_acc did not improve from 0.86745
# Epoch 00034: early stopping
# acc: 88.45%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
#
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
#
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00019: val_acc did not improve from 0.86745
#
# Epoch 00020: val_acc did not improve from 0.86745
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00021: val_acc did not improve from 0.86745
#
# Epoch 00022: val_acc did not improve from 0.86745
#
# Epoch 00023: val_acc did not improve from 0.86745
#
# Epoch 00024: val_acc did not improve from 0.86745
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00030: val_acc did not improve from 0.86745
#
# Epoch 00031: val_acc did not improve from 0.86745
#
# Epoch 00032: val_acc did not improve from 0.86745
# Epoch 00032: early stopping
# acc: 87.79%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00019: val_acc did not improve from 0.86745
# Epoch 00019: early stopping
# acc: 87.09%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
#
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
#
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00019: val_acc did not improve from 0.86745
#
# Epoch 00020: val_acc did not improve from 0.86745
#
# Epoch 00021: val_acc did not improve from 0.86745
#
# Epoch 00022: val_acc did not improve from 0.86745
#
# Epoch 00023: val_acc did not improve from 0.86745
#
# Epoch 00024: val_acc did not improve from 0.86745
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00030: val_acc did not improve from 0.86745
#
# Epoch 00031: val_acc did not improve from 0.86745
#
# Epoch 00032: val_acc did not improve from 0.86745
#
# Epoch 00033: val_acc did not improve from 0.86745
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00034: val_acc did not improve from 0.86745
#
# Epoch 00035: val_acc did not improve from 0.86745
#
# Epoch 00036: val_acc did not improve from 0.86745
# Epoch 00036: early stopping
# acc: 87.80%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
#
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
#
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_acc did not improve from 0.86745
#
# Epoch 00020: val_acc did not improve from 0.86745
#
# Epoch 00021: val_acc did not improve from 0.86745
#
# Epoch 00022: val_acc did not improve from 0.86745
#
# Epoch 00023: val_acc did not improve from 0.86745
#
# Epoch 00024: val_acc did not improve from 0.86745
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00030: val_acc did not improve from 0.86745
#
# Epoch 00031: val_acc did not improve from 0.86745
#
# Epoch 00032: val_acc did not improve from 0.86745
#
# Epoch 00033: val_acc did not improve from 0.86745
#
# Epoch 00034: val_acc did not improve from 0.86745
#
# Epoch 00035: val_acc did not improve from 0.86745
#
# Epoch 00036: val_acc did not improve from 0.86745
#
# Epoch 00037: val_acc did not improve from 0.86745
#
# Epoch 00038: val_acc did not improve from 0.86745
#
# Epoch 00039: val_acc did not improve from 0.86745
#
# Epoch 00040: val_acc did not improve from 0.86745
#
# Epoch 00041: val_acc did not improve from 0.86745
#
# Epoch 00042: val_acc did not improve from 0.86745
#
# Epoch 00043: val_acc did not improve from 0.86745
#
# Epoch 00044: val_acc did not improve from 0.86745
#
# Epoch 00045: val_acc did not improve from 0.86745
#
# Epoch 00046: val_acc did not improve from 0.86745
#
# Epoch 00047: val_acc did not improve from 0.86745
#
# Epoch 00048: val_acc did not improve from 0.86745
#
# Epoch 00049: val_acc did not improve from 0.86745
#
# Epoch 00050: val_acc did not improve from 0.86745
#
# Epoch 00051: val_acc did not improve from 0.86745
#
# Epoch 00052: val_acc did not improve from 0.86745
#
# Epoch 00053: val_acc did not improve from 0.86745
#
# Epoch 00054: val_acc did not improve from 0.86745
#
# Epoch 00055: val_acc did not improve from 0.86745
#
# Epoch 00056: val_acc did not improve from 0.86745
#
# Epoch 00057: val_acc did not improve from 0.86745
#
# Epoch 00058: val_acc did not improve from 0.86745
#
# Epoch 00059: val_acc did not improve from 0.86745
#
# Epoch 00060: val_acc did not improve from 0.86745
#
# Epoch 00061: val_acc did not improve from 0.86745
#
# Epoch 00062: val_acc did not improve from 0.86745
#
# Epoch 00063: val_acc did not improve from 0.86745
#
# Epoch 00064: val_acc did not improve from 0.86745
#
# Epoch 00065: val_acc did not improve from 0.86745
#
# Epoch 00066: val_acc did not improve from 0.86745
#
# Epoch 00067: val_acc did not improve from 0.86745
#
# Epoch 00068: val_acc did not improve from 0.86745
#
# Epoch 00069: val_acc did not improve from 0.86745
#
# Epoch 00070: val_acc did not improve from 0.86745
#
# Epoch 00071: val_acc did not improve from 0.86745
#
# Epoch 00072: val_acc did not improve from 0.86745
#
# Epoch 00073: val_acc did not improve from 0.86745
#
# Epoch 00074: val_acc did not improve from 0.86745
#
# Epoch 00075: val_acc did not improve from 0.86745
#
# Epoch 00076: val_acc did not improve from 0.86745
#
# Epoch 00077: val_acc did not improve from 0.86745
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00078: val_acc did not improve from 0.86745
#
# Epoch 00079: val_acc did not improve from 0.86745
#
# Epoch 00080: val_acc did not improve from 0.86745
#
# Epoch 00081: val_acc did not improve from 0.86745
#
# Epoch 00082: val_acc did not improve from 0.86745
#
# Epoch 00083: val_acc did not improve from 0.86745
#
# Epoch 00084: val_acc did not improve from 0.86745
#
# Epoch 00085: val_acc did not improve from 0.86745
#
# Epoch 00086: val_acc did not improve from 0.86745
#
# Epoch 00087: val_acc did not improve from 0.86745
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00088: val_acc did not improve from 0.86745
#
# Epoch 00089: val_acc did not improve from 0.86745
#
# Epoch 00090: val_acc did not improve from 0.86745
# Epoch 00090: early stopping
# acc: 88.80%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
#
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00019: val_acc did not improve from 0.86745
#
# Epoch 00020: val_acc did not improve from 0.86745
#
# Epoch 00021: val_acc did not improve from 0.86745
#
# Epoch 00022: val_acc did not improve from 0.86745
#
# Epoch 00023: val_acc did not improve from 0.86745
#
# Epoch 00024: val_acc did not improve from 0.86745
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00030: val_acc did not improve from 0.86745
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00031: val_acc did not improve from 0.86745
#
# Epoch 00032: val_acc did not improve from 0.86745
#
# Epoch 00033: val_acc did not improve from 0.86745
# Epoch 00033: early stopping
# acc: 86.61%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
#
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
#
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00019: val_acc did not improve from 0.86745
#
# Epoch 00020: val_acc did not improve from 0.86745
#
# Epoch 00021: val_acc did not improve from 0.86745
#
# Epoch 00022: val_acc did not improve from 0.86745
#
# Epoch 00023: val_acc did not improve from 0.86745
#
# Epoch 00024: val_acc did not improve from 0.86745
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00030: val_acc did not improve from 0.86745
#
# Epoch 00031: val_acc did not improve from 0.86745
#
# Epoch 00032: val_acc did not improve from 0.86745
#
# Epoch 00033: val_acc did not improve from 0.86745
#
# Epoch 00034: val_acc did not improve from 0.86745
#
# Epoch 00035: val_acc did not improve from 0.86745
#
# Epoch 00036: val_acc did not improve from 0.86745
#
# Epoch 00037: val_acc did not improve from 0.86745
#
# Epoch 00038: val_acc did not improve from 0.86745
#
# Epoch 00039: val_acc did not improve from 0.86745
#
# Epoch 00040: val_acc did not improve from 0.86745
#
# Epoch 00041: val_acc did not improve from 0.86745
#
# Epoch 00042: val_acc did not improve from 0.86745
#
# Epoch 00043: val_acc did not improve from 0.86745
#
# Epoch 00044: val_acc did not improve from 0.86745
#
# Epoch 00045: val_acc did not improve from 0.86745
#
# Epoch 00046: val_acc did not improve from 0.86745
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00047: val_acc did not improve from 0.86745
#
# Epoch 00048: val_acc did not improve from 0.86745
#
# Epoch 00049: val_acc did not improve from 0.86745
# Epoch 00049: early stopping
# acc: 88.45%
#
# Epoch 00001: val_acc did not improve from 0.86745
#
# Epoch 00002: val_acc did not improve from 0.86745
#
# Epoch 00003: val_acc did not improve from 0.86745
#
# Epoch 00004: val_acc did not improve from 0.86745
#
# Epoch 00005: val_acc did not improve from 0.86745
#
# Epoch 00006: val_acc did not improve from 0.86745
#
# Epoch 00007: val_acc did not improve from 0.86745
#
# Epoch 00008: val_acc did not improve from 0.86745
#
# Epoch 00009: val_acc did not improve from 0.86745
#
# Epoch 00010: val_acc did not improve from 0.86745
#
# Epoch 00011: val_acc did not improve from 0.86745
#
# Epoch 00012: val_acc did not improve from 0.86745
#
# Epoch 00013: val_acc did not improve from 0.86745
#
# Epoch 00014: val_acc did not improve from 0.86745
#
# Epoch 00015: val_acc did not improve from 0.86745
#
# Epoch 00016: val_acc did not improve from 0.86745
#
# Epoch 00017: val_acc did not improve from 0.86745
#
# Epoch 00018: val_acc did not improve from 0.86745
#
# Epoch 00019: val_acc did not improve from 0.86745
#
# Epoch 00020: val_acc did not improve from 0.86745
#
# Epoch 00021: val_acc did not improve from 0.86745
#
# Epoch 00022: val_acc did not improve from 0.86745
#
# Epoch 00023: val_acc did not improve from 0.86745
#
# Epoch 00024: val_acc did not improve from 0.86745
#
# Epoch 00025: val_acc did not improve from 0.86745
#
# Epoch 00026: val_acc did not improve from 0.86745
#
# Epoch 00027: val_acc did not improve from 0.86745
#
# Epoch 00028: val_acc did not improve from 0.86745
#
# Epoch 00029: val_acc did not improve from 0.86745
#
# Epoch 00030: val_acc improved from 0.86745 to 0.88822, saving model to baseline_cnn_ecgview_kfolds.h5
#
# Epoch 00031: val_acc did not improve from 0.88822
#
# Epoch 00032: val_acc did not improve from 0.88822
#
# Epoch 00033: val_acc did not improve from 0.88822
#
# Epoch 00034: val_acc did not improve from 0.88822
#
# Epoch 00035: val_acc did not improve from 0.88822
#
# Epoch 00036: val_acc did not improve from 0.88822
#
# Epoch 00037: val_acc did not improve from 0.88822
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00038: val_acc did not improve from 0.88822
#
# Epoch 00039: val_acc did not improve from 0.88822
#
# Epoch 00040: val_acc did not improve from 0.88822
# Epoch 00040: early stopping
# acc: 88.93%
# 88.01% (+/- 0.75%)
