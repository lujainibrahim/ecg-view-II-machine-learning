# %% [markdown]
# # CNN Training

# %% [markdown]
# From our paper on "Explainable Prediction of Acute Myocardial Infarction using Machine Learning and Shapley Values"

# %%
# Import libraries
import pandas as pd
import numpy as np
import pylab as plt
from keras import optimizers, losses, activations, models, regularizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, Flatten, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate
from keras.utils import to_categorical
from keras.models import load_model, Sequential
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Loading Data

# %%
# Load data
# Import train and test data into dataframes from csv files produced using the data processing code
df_cnn_train = pd.read_csv("train.csv", header=None)
df_cnn_train = df_cnn_train.sample(frac=1)
df_cnn_test = pd.read_csv("test.csv", header=None)

# %%
# Get data from dataframes
y_cnn = np.array(df_cnn_train[11].values).astype(np.int8)
y_cnn=to_categorical(y_cnn)
x_cnn = np.array(df_cnn_train[list(range(11))].values)[..., np.newaxis]
y_cnn_test = np.array(df_cnn_test[11].values).astype(np.int8)
x_cnn_test = np.array(df_cnn_test[list(range(11))].values)[..., np.newaxis]

# %% [markdown]
# # Model Definition + Training

# %%
# Model definition
def get_model(learning_rate=0.001):
    nclass = 2
    inp = Input(shape=(11, 1))
    
    cnn = Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid")(inp)
    cnn = Dropout(rate=0.1)(cnn) 
    cnn = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(cnn)
    cnn = Dropout(rate=0.1)(cnn)
    cnn = Convolution1D(64, kernel_size=3, activation=activations.relu, padding="valid")(cnn)
    cnn = Dropout(rate=0.1)(cnn)
    cnn = Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid")(cnn)
    cnn = GlobalMaxPool1D()(cnn)
    cnn = Dropout(rate=0.1)(cnn)
    dense_1 = Dense(64, activation=activations.relu, name="dense_1", kernel_regularizer=regularizers.l2(l=0.1))(cnn)
    dense_1 = Dense(16, activation=activations.relu, name="dense_2", kernel_regularizer=regularizers.l2(l=0.1))(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_ecg_view")(dense_1) 
    

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(learning_rate)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=['acc'])
    return model

# %%
# Model Training
# Load model and model summary
model = get_model()
model.summary()

# File path to save the model
file_path = "cnn_ecgview.h5"

# Checkpoint the model's weight based on the accuracy of the model
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# Set early stopping based on accuracy. It stops after 10 consecutive epochs of no accuracy improvement.
early = EarlyStopping(monitor="val_acc", mode="max", patience=10, verbose=1)

# Reduce learning rate based on accuracy. It reduces the rate after 7 consecutive epochs of no accuracy improvement.
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=7, verbose=2)

callbacks_list = [checkpoint, early, redonplat]

# Train the model, load weights into above file path to save the model
model.fit(x_cnn, y_cnn, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

# The file will be saved in the file_path and can be loaded later using Keras for evaluation
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 11, 1)             0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 7, 16)             96
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 16)             0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 5, 32)             1568
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 32)             0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 3, 64)             6208
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 3, 64)             0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1, 256)            49408
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_3_ecg_view (Dense)     (None, 2)                 34
# =================================================================
# Total params: 74,802
# Trainable params: 74,802
# Non-trainable params: 0
# _________________________________________________________________
# Train on 380727 samples, validate on 42304 samples
# Epoch 1/1000
#  - 61s - loss: 0.4772 - acc: 0.8013 - val_loss: 0.3919 - val_acc: 0.8244
#
# Epoch 00001: val_acc improved from -inf to 0.82437, saving model to baseline_cnn_ecgview.h5
# Epoch 2/1000
#  - 59s - loss: 0.3940 - acc: 0.8186 - val_loss: 0.3721 - val_acc: 0.8320
#
# Epoch 00002: val_acc improved from 0.82437 to 0.83195, saving model to baseline_cnn_ecgview.h5
# Epoch 3/1000
#  - 59s - loss: 0.3832 - acc: 0.8240 - val_loss: 0.3715 - val_acc: 0.8332
#
# Epoch 00003: val_acc improved from 0.83195 to 0.83318, saving model to baseline_cnn_ecgview.h5
# Epoch 4/1000
#  - 56s - loss: 0.3777 - acc: 0.8268 - val_loss: 0.3585 - val_acc: 0.8368
#
# Epoch 00004: val_acc improved from 0.83318 to 0.83682, saving model to baseline_cnn_ecgview.h5
# Epoch 5/1000
#  - 66s - loss: 0.3718 - acc: 0.8300 - val_loss: 0.3481 - val_acc: 0.8414
#
# Epoch 00005: val_acc improved from 0.83682 to 0.84139, saving model to baseline_cnn_ecgview.h5
# Epoch 6/1000
#  - 63s - loss: 0.3673 - acc: 0.8318 - val_loss: 0.3442 - val_acc: 0.8461
#
# Epoch 00006: val_acc improved from 0.84139 to 0.84607, saving model to baseline_cnn_ecgview.h5
# Epoch 7/1000
#  - 51s - loss: 0.3643 - acc: 0.8331 - val_loss: 0.3424 - val_acc: 0.8452
#
# Epoch 00007: val_acc did not improve from 0.84607
# Epoch 8/1000
#  - 53s - loss: 0.3604 - acc: 0.8355 - val_loss: 0.3362 - val_acc: 0.8519
#
# Epoch 00008: val_acc improved from 0.84607 to 0.85186, saving model to baseline_cnn_ecgview.h5
# Epoch 9/1000
#  - 63s - loss: 0.3580 - acc: 0.8366 - val_loss: 0.3341 - val_acc: 0.8494
#
# Epoch 00009: val_acc did not improve from 0.85186
# Epoch 10/1000
#  - 63s - loss: 0.3553 - acc: 0.8379 - val_loss: 0.3319 - val_acc: 0.8522
#
# Epoch 00010: val_acc improved from 0.85186 to 0.85219, saving model to baseline_cnn_ecgview.h5
# Epoch 11/1000
#  - 56s - loss: 0.3535 - acc: 0.8396 - val_loss: 0.3293 - val_acc: 0.8550
#
# Epoch 00011: val_acc improved from 0.85219 to 0.85505, saving model to baseline_cnn_ecgview.h5
# Epoch 12/1000
#  - 62s - loss: 0.3514 - acc: 0.8407 - val_loss: 0.3271 - val_acc: 0.8538
#
# Epoch 00012: val_acc did not improve from 0.85505
# Epoch 13/1000
#  - 66s - loss: 0.3493 - acc: 0.8415 - val_loss: 0.3192 - val_acc: 0.8576
#
# Epoch 00013: val_acc improved from 0.85505 to 0.85760, saving model to baseline_cnn_ecgview.h5
# Epoch 14/1000
#  - 52s - loss: 0.3479 - acc: 0.8424 - val_loss: 0.3189 - val_acc: 0.8585
#
# Epoch 00014: val_acc improved from 0.85760 to 0.85848, saving model to baseline_cnn_ecgview.h5
# Epoch 15/1000
#  - 62s - loss: 0.3467 - acc: 0.8424 - val_loss: 0.3186 - val_acc: 0.8579
#
# Epoch 00015: val_acc did not improve from 0.85848
# Epoch 16/1000
#  - 52s - loss: 0.3450 - acc: 0.8440 - val_loss: 0.3132 - val_acc: 0.8640
#
# Epoch 00016: val_acc improved from 0.85848 to 0.86396, saving model to baseline_cnn_ecgview.h5
# Epoch 17/1000
#  - 44s - loss: 0.3434 - acc: 0.8446 - val_loss: 0.3093 - val_acc: 0.8649
#
# Epoch 00017: val_acc improved from 0.86396 to 0.86493, saving model to baseline_cnn_ecgview.h5
# Epoch 18/1000
#  - 44s - loss: 0.3427 - acc: 0.8454 - val_loss: 0.3099 - val_acc: 0.8628
#
# Epoch 00018: val_acc did not improve from 0.86493
# Epoch 19/1000
#  - 44s - loss: 0.3407 - acc: 0.8463 - val_loss: 0.3113 - val_acc: 0.8636
#
# Epoch 00019: val_acc did not improve from 0.86493
# Epoch 20/1000
#  - 44s - loss: 0.3393 - acc: 0.8475 - val_loss: 0.3069 - val_acc: 0.8647
#
# Epoch 00020: val_acc did not improve from 0.86493
# Epoch 21/1000
#  - 44s - loss: 0.3390 - acc: 0.8473 - val_loss: 0.3130 - val_acc: 0.8634
#
# Epoch 00021: val_acc did not improve from 0.86493
# Epoch 22/1000
#  - 43s - loss: 0.3379 - acc: 0.8484 - val_loss: 0.3114 - val_acc: 0.8694
#
# Epoch 00022: val_acc improved from 0.86493 to 0.86940, saving model to baseline_cnn_ecgview.h5
# Epoch 23/1000
#  - 44s - loss: 0.3375 - acc: 0.8483 - val_loss: 0.3096 - val_acc: 0.8678
#
# Epoch 00023: val_acc did not improve from 0.86940
# Epoch 24/1000
#  - 44s - loss: 0.3361 - acc: 0.8488 - val_loss: 0.3011 - val_acc: 0.8711
#
# Epoch 00024: val_acc improved from 0.86940 to 0.87110, saving model to baseline_cnn_ecgview.h5
# Epoch 25/1000
#  - 43s - loss: 0.3349 - acc: 0.8497 - val_loss: 0.3002 - val_acc: 0.8721
#
# Epoch 00025: val_acc improved from 0.87110 to 0.87209, saving model to baseline_cnn_ecgview.h5
# Epoch 26/1000
#  - 49s - loss: 0.3338 - acc: 0.8505 - val_loss: 0.3032 - val_acc: 0.8693
#
# Epoch 00026: val_acc did not improve from 0.87209
# Epoch 27/1000
#  - 60s - loss: 0.3330 - acc: 0.8511 - val_loss: 0.3023 - val_acc: 0.8707
#
# Epoch 00027: val_acc did not improve from 0.87209
# Epoch 28/1000
#  - 53s - loss: 0.3321 - acc: 0.8515 - val_loss: 0.2975 - val_acc: 0.8725
#
# Epoch 00028: val_acc improved from 0.87209 to 0.87247, saving model to baseline_cnn_ecgview.h5
# Epoch 29/1000
#  - 54s - loss: 0.3319 - acc: 0.8511 - val_loss: 0.3052 - val_acc: 0.8684
#
# Epoch 00029: val_acc did not improve from 0.87247
# Epoch 30/1000
#  - 61s - loss: 0.3305 - acc: 0.8523 - val_loss: 0.3004 - val_acc: 0.8746
#
# Epoch 00030: val_acc improved from 0.87247 to 0.87457, saving model to baseline_cnn_ecgview.h5
# Epoch 31/1000
#  - 57s - loss: 0.3301 - acc: 0.8527 - val_loss: 0.2983 - val_acc: 0.8715
#
# Epoch 00031: val_acc did not improve from 0.87457
# Epoch 32/1000
#  - 49s - loss: 0.3291 - acc: 0.8528 - val_loss: 0.2977 - val_acc: 0.8721
#
# Epoch 00032: val_acc did not improve from 0.87457
# Epoch 33/1000
#  - 44s - loss: 0.3285 - acc: 0.8535 - val_loss: 0.2907 - val_acc: 0.8799
#
# Epoch 00033: val_acc improved from 0.87457 to 0.87994, saving model to baseline_cnn_ecgview.h5
# Epoch 34/1000
#  - 44s - loss: 0.3281 - acc: 0.8540 - val_loss: 0.2907 - val_acc: 0.8778
#
# Epoch 00034: val_acc did not improve from 0.87994
# Epoch 35/1000
#  - 44s - loss: 0.3276 - acc: 0.8538 - val_loss: 0.2926 - val_acc: 0.8758
#
# Epoch 00035: val_acc did not improve from 0.87994
# Epoch 36/1000
#  - 44s - loss: 0.3273 - acc: 0.8545 - val_loss: 0.2897 - val_acc: 0.8766
#
# Epoch 00036: val_acc did not improve from 0.87994
# Epoch 37/1000
#  - 49s - loss: 0.3268 - acc: 0.8546 - val_loss: 0.2853 - val_acc: 0.8781
#
# Epoch 00037: val_acc did not improve from 0.87994
# Epoch 38/1000
#  - 49s - loss: 0.3259 - acc: 0.8551 - val_loss: 0.2938 - val_acc: 0.8743
#
# Epoch 00038: val_acc did not improve from 0.87994
# Epoch 39/1000
#  - 64s - loss: 0.3249 - acc: 0.8561 - val_loss: 0.2843 - val_acc: 0.8802
#
# Epoch 00039: val_acc improved from 0.87994 to 0.88018, saving model to baseline_cnn_ecgview.h5
# Epoch 40/1000
#  - 60s - loss: 0.3254 - acc: 0.8559 - val_loss: 0.2930 - val_acc: 0.8748
#
# Epoch 00040: val_acc did not improve from 0.88018
# Epoch 41/1000
#  - 57s - loss: 0.3245 - acc: 0.8559 - val_loss: 0.2832 - val_acc: 0.8833
#
# Epoch 00041: val_acc improved from 0.88018 to 0.88330, saving model to baseline_cnn_ecgview.h5
# Epoch 42/1000
#  - 53s - loss: 0.3232 - acc: 0.8567 - val_loss: 0.2892 - val_acc: 0.8819
#
# Epoch 00042: val_acc did not improve from 0.88330
# Epoch 43/1000
#  - 64s - loss: 0.3231 - acc: 0.8575 - val_loss: 0.2904 - val_acc: 0.8779
#
# Epoch 00043: val_acc did not improve from 0.88330
# Epoch 44/1000
#  - 52s - loss: 0.3225 - acc: 0.8574 - val_loss: 0.2773 - val_acc: 0.8826
#
# Epoch 00044: val_acc did not improve from 0.88330
# Epoch 45/1000
#  - 53s - loss: 0.3225 - acc: 0.8575 - val_loss: 0.2926 - val_acc: 0.8746
#
# Epoch 00045: val_acc did not improve from 0.88330
# Epoch 46/1000
#  - 54s - loss: 0.3215 - acc: 0.8581 - val_loss: 0.2854 - val_acc: 0.8854
#
# Epoch 00046: val_acc improved from 0.88330 to 0.88535, saving model to baseline_cnn_ecgview.h5
# Epoch 47/1000
#  - 51s - loss: 0.3216 - acc: 0.8580 - val_loss: 0.2803 - val_acc: 0.8849
#
# Epoch 00047: val_acc did not improve from 0.88535
# Epoch 48/1000
#  - 52s - loss: 0.3199 - acc: 0.8591 - val_loss: 0.2774 - val_acc: 0.8845
#
# Epoch 00048: val_acc did not improve from 0.88535
# Epoch 49/1000
#  - 51s - loss: 0.3205 - acc: 0.8582 - val_loss: 0.2793 - val_acc: 0.8840
#
# Epoch 00049: val_acc did not improve from 0.88535
# Epoch 50/1000
#  - 50s - loss: 0.3199 - acc: 0.8592 - val_loss: 0.2756 - val_acc: 0.8866
#
# Epoch 00050: val_acc improved from 0.88535 to 0.88661, saving model to baseline_cnn_ecgview.h5
# Epoch 51/1000
#  - 53s - loss: 0.3192 - acc: 0.8590 - val_loss: 0.2753 - val_acc: 0.8854
#
# Epoch 00051: val_acc did not improve from 0.88661
# Epoch 52/1000
#  - 51s - loss: 0.3198 - acc: 0.8590 - val_loss: 0.2731 - val_acc: 0.8871
#
# Epoch 00052: val_acc improved from 0.88661 to 0.88713, saving model to baseline_cnn_ecgview.h5
# Epoch 53/1000
#  - 58s - loss: 0.3189 - acc: 0.8596 - val_loss: 0.2784 - val_acc: 0.8846
#
# Epoch 00053: val_acc did not improve from 0.88713
# Epoch 54/1000
#  - 68s - loss: 0.3188 - acc: 0.8592 - val_loss: 0.2813 - val_acc: 0.8857
#
# Epoch 00054: val_acc did not improve from 0.88713
# Epoch 55/1000
#  - 49s - loss: 0.3177 - acc: 0.8600 - val_loss: 0.2749 - val_acc: 0.8849
#
# Epoch 00055: val_acc did not improve from 0.88713
# Epoch 56/1000
#  - 56s - loss: 0.3178 - acc: 0.8604 - val_loss: 0.2749 - val_acc: 0.8837
#
# Epoch 00056: val_acc did not improve from 0.88713
# Epoch 57/1000
#  - 51s - loss: 0.3171 - acc: 0.8608 - val_loss: 0.2840 - val_acc: 0.8766
#
# Epoch 00057: val_acc did not improve from 0.88713
# Epoch 58/1000
#  - 48s - loss: 0.3174 - acc: 0.8603 - val_loss: 0.2800 - val_acc: 0.8827
#
# Epoch 00058: val_acc did not improve from 0.88713
# Epoch 59/1000
#  - 49s - loss: 0.3168 - acc: 0.8604 - val_loss: 0.2764 - val_acc: 0.8873
#
# Epoch 00059: val_acc improved from 0.88713 to 0.88734, saving model to baseline_cnn_ecgview.h5
# Epoch 60/1000
#  - 48s - loss: 0.3158 - acc: 0.8616 - val_loss: 0.2830 - val_acc: 0.8774
#
# Epoch 00060: val_acc did not improve from 0.88734
# Epoch 61/1000
#  - 50s - loss: 0.3155 - acc: 0.8611 - val_loss: 0.2778 - val_acc: 0.8845
#
# Epoch 00061: val_acc did not improve from 0.88734
# Epoch 62/1000
#  - 49s - loss: 0.3162 - acc: 0.8611 - val_loss: 0.2715 - val_acc: 0.8859
#
# Epoch 00062: val_acc did not improve from 0.88734
# Epoch 63/1000
#  - 55s - loss: 0.3154 - acc: 0.8612 - val_loss: 0.2855 - val_acc: 0.8789
#
# Epoch 00063: val_acc did not improve from 0.88734
# Epoch 64/1000
#  - 50s - loss: 0.3146 - acc: 0.8617 - val_loss: 0.2826 - val_acc: 0.8774
#
# Epoch 00064: val_acc did not improve from 0.88734
# Epoch 65/1000
#  - 49s - loss: 0.3145 - acc: 0.8622 - val_loss: 0.2700 - val_acc: 0.8899
#
# Epoch 00065: val_acc improved from 0.88734 to 0.88987, saving model to baseline_cnn_ecgview.h5
# Epoch 66/1000
#  - 50s - loss: 0.3144 - acc: 0.8618 - val_loss: 0.2692 - val_acc: 0.8898
#
# Epoch 00066: val_acc did not improve from 0.88987
# Epoch 67/1000
#  - 50s - loss: 0.3134 - acc: 0.8629 - val_loss: 0.2815 - val_acc: 0.8864
#
# Epoch 00067: val_acc did not improve from 0.88987
# Epoch 68/1000
#  - 52s - loss: 0.3141 - acc: 0.8621 - val_loss: 0.2743 - val_acc: 0.8836
#
# Epoch 00068: val_acc did not improve from 0.88987
# Epoch 69/1000
#  - 50s - loss: 0.3143 - acc: 0.8624 - val_loss: 0.2726 - val_acc: 0.8860
#
# Epoch 00069: val_acc did not improve from 0.88987
# Epoch 70/1000
#  - 48s - loss: 0.3131 - acc: 0.8624 - val_loss: 0.2814 - val_acc: 0.8793
#
# Epoch 00070: val_acc did not improve from 0.88987
# Epoch 71/1000
#  - 51s - loss: 0.3135 - acc: 0.8626 - val_loss: 0.2688 - val_acc: 0.8858
#
# Epoch 00071: val_acc did not improve from 0.88987
# Epoch 72/1000
#  - 61s - loss: 0.3128 - acc: 0.8633 - val_loss: 0.2667 - val_acc: 0.8911
#
# Epoch 00072: val_acc improved from 0.88987 to 0.89105, saving model to baseline_cnn_ecgview.h5
# Epoch 73/1000
#  - 59s - loss: 0.3124 - acc: 0.8636 - val_loss: 0.2767 - val_acc: 0.8844
#
# Epoch 00073: val_acc did not improve from 0.89105
# Epoch 74/1000
#  - 57s - loss: 0.3122 - acc: 0.8638 - val_loss: 0.2749 - val_acc: 0.8845
#
# Epoch 00074: val_acc did not improve from 0.89105
# Epoch 75/1000
#  - 68s - loss: 0.3108 - acc: 0.8646 - val_loss: 0.2716 - val_acc: 0.8872
#
# Epoch 00075: val_acc did not improve from 0.89105
# Epoch 76/1000
#  - 49s - loss: 0.3120 - acc: 0.8639 - val_loss: 0.2669 - val_acc: 0.8921
#
# Epoch 00076: val_acc improved from 0.89105 to 0.89209, saving model to baseline_cnn_ecgview.h5
# Epoch 77/1000
#  - 53s - loss: 0.3112 - acc: 0.8637 - val_loss: 0.2808 - val_acc: 0.8809
#
# Epoch 00077: val_acc did not improve from 0.89209
# Epoch 78/1000
#  - 50s - loss: 0.3117 - acc: 0.8638 - val_loss: 0.2640 - val_acc: 0.8931
#
# Epoch 00078: val_acc improved from 0.89209 to 0.89311, saving model to baseline_cnn_ecgview.h5
# Epoch 79/1000
#  - 51s - loss: 0.3106 - acc: 0.8641 - val_loss: 0.2761 - val_acc: 0.8840
#
# Epoch 00079: val_acc did not improve from 0.89311
# Epoch 80/1000
#  - 52s - loss: 0.3103 - acc: 0.8642 - val_loss: 0.2655 - val_acc: 0.8918
#
# Epoch 00080: val_acc did not improve from 0.89311
# Epoch 81/1000
#  - 52s - loss: 0.3108 - acc: 0.8641 - val_loss: 0.2705 - val_acc: 0.8890
#
# Epoch 00081: val_acc did not improve from 0.89311
# Epoch 82/1000
#  - 50s - loss: 0.3095 - acc: 0.8646 - val_loss: 0.2741 - val_acc: 0.8882
#
# Epoch 00082: val_acc did not improve from 0.89311
# Epoch 83/1000
#  - 45s - loss: 0.3102 - acc: 0.8650 - val_loss: 0.2775 - val_acc: 0.8842
#
# Epoch 00083: val_acc did not improve from 0.89311
# Epoch 84/1000
#  - 54s - loss: 0.3094 - acc: 0.8649 - val_loss: 0.2683 - val_acc: 0.8924
#
# Epoch 00084: val_acc did not improve from 0.89311
# Epoch 85/1000
#  - 48s - loss: 0.3086 - acc: 0.8652 - val_loss: 0.2672 - val_acc: 0.8930
#
# Epoch 00085: val_acc did not improve from 0.89311
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 86/1000
#  - 46s - loss: 0.2987 - acc: 0.8697 - val_loss: 0.2571 - val_acc: 0.8945
#
# Epoch 00086: val_acc improved from 0.89311 to 0.89450, saving model to baseline_cnn_ecgview.h5
# Epoch 87/1000
#  - 44s - loss: 0.2945 - acc: 0.8710 - val_loss: 0.2541 - val_acc: 0.8947
#
# Epoch 00087: val_acc improved from 0.89450 to 0.89474, saving model to baseline_cnn_ecgview.h5
# Epoch 88/1000
#  - 45s - loss: 0.2945 - acc: 0.8710 - val_loss: 0.2540 - val_acc: 0.8949
#
# Epoch 00088: val_acc improved from 0.89474 to 0.89490, saving model to baseline_cnn_ecgview.h5
# Epoch 89/1000
#  - 45s - loss: 0.2943 - acc: 0.8707 - val_loss: 0.2557 - val_acc: 0.8922
#
# Epoch 00089: val_acc did not improve from 0.89490
# Epoch 90/1000
#  - 46s - loss: 0.2936 - acc: 0.8711 - val_loss: 0.2525 - val_acc: 0.8943
#
# Epoch 00090: val_acc did not improve from 0.89490
# Epoch 91/1000
#  - 44s - loss: 0.2927 - acc: 0.8717 - val_loss: 0.2542 - val_acc: 0.8938
#
# Epoch 00091: val_acc did not improve from 0.89490
# Epoch 92/1000
#  - 53s - loss: 0.2924 - acc: 0.8722 - val_loss: 0.2482 - val_acc: 0.8979
#
# Epoch 00092: val_acc improved from 0.89490 to 0.89793, saving model to baseline_cnn_ecgview.h5
# Epoch 93/1000
#  - 46s - loss: 0.2925 - acc: 0.8729 - val_loss: 0.2521 - val_acc: 0.8954
# Epoch 00093: val_acc did not improve from 0.89793
# Epoch 94/1000
#  - 56s - loss: 0.2923 - acc: 0.8723 - val_loss: 0.2495 - val_acc: 0.8982
#
# Epoch 00094: val_acc improved from 0.89793 to 0.89819, saving model to baseline_cnn_ecgview.h5
# Epoch 95/1000
#  - 48s - loss: 0.2918 - acc: 0.8726 - val_loss: 0.2486 - val_acc: 0.8980
#
# Epoch 00095: val_acc did not improve from 0.89819
# Epoch 96/1000
#  - 46s - loss: 0.2917 - acc: 0.8725 - val_loss: 0.2482 - val_acc: 0.8993
#
# Epoch 00096: val_acc improved from 0.89819 to 0.89930, saving model to baseline_cnn_ecgview.h5
# Epoch 97/1000
#  - 52s - loss: 0.2920 - acc: 0.8720 - val_loss: 0.2499 - val_acc: 0.8970
#
# Epoch 00097: val_acc did not improve from 0.89930
# Epoch 98/1000
#  - 60s - loss: 0.2920 - acc: 0.8725 - val_loss: 0.2468 - val_acc: 0.8996
#
# Epoch 00098: val_acc improved from 0.89930 to 0.89958, saving model to baseline_cnn_ecgview.h5
# Epoch 99/1000
#  - 55s - loss: 0.2905 - acc: 0.8733 - val_loss: 0.2479 - val_acc: 0.8976
#
# Epoch 00099: val_acc did not improve from 0.89958
# Epoch 100/1000
#  - 58s - loss: 0.2923 - acc: 0.8721 - val_loss: 0.2473 - val_acc: 0.8977
#
# Epoch 00100: val_acc did not improve from 0.89958
# Epoch 101/1000
#  - 55s - loss: 0.2915 - acc: 0.8725 - val_loss: 0.2472 - val_acc: 0.8986
#
# Epoch 00101: val_acc did not improve from 0.89958
# Epoch 102/1000
#  - 43s - loss: 0.2910 - acc: 0.8727 - val_loss: 0.2487 - val_acc: 0.8989
#
# Epoch 00102: val_acc did not improve from 0.89958
# Epoch 103/1000
#  - 43s - loss: 0.2918 - acc: 0.8722 - val_loss: 0.2519 - val_acc: 0.8945
#
# Epoch 00103: val_acc did not improve from 0.89958
# Epoch 104/1000
#  - 43s - loss: 0.2905 - acc: 0.8732 - val_loss: 0.2529 - val_acc: 0.8945
#
# Epoch 00104: val_acc did not improve from 0.89958
# Epoch 105/1000
#  - 53s - loss: 0.2900 - acc: 0.8737 - val_loss: 0.2507 - val_acc: 0.8963
#
# Epoch 00105: val_acc did not improve from 0.89958
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 106/1000
#  - 49s - loss: 0.2894 - acc: 0.8734 - val_loss: 0.2472 - val_acc: 0.8973
#
# Epoch 00106: val_acc did not improve from 0.89958
# Epoch 107/1000
#  - 55s - loss: 0.2891 - acc: 0.8738 - val_loss: 0.2471 - val_acc: 0.8973
#
# Epoch 00107: val_acc did not improve from 0.89958
# Epoch 108/1000
#  - 47s - loss: 0.2888 - acc: 0.8744 - val_loss: 0.2468 - val_acc: 0.8980
#
# Epoch 00108: val_acc did not improve from 0.89958
# Epoch 00108: early stopping
