# %% [markdown]
# # CNN Training

# %% [markdown]
# From our paper on "Explainable Prediction of Acute Myocardial Infarction using Machine Learning and Shapley Values"

# %%
# Import libraries
import pandas as pd
import numpy as np
import pylab as plt
from keras import optimizers, losses, activations, models, regularizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, Flatten, GlobalMaxPool1D, GlobalAveragePooling1D, \
    concatenate
from keras.utils import to_categorical
from keras.models import load_model, Sequential
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading Data

# %%
# Load data
# Import train and test data into dataframes from csv files produced using the data processing code
df_cnn_train = pd.read_csv("train_noagesex.csv", header=None)
df_cnn_train = df_cnn_train.sample(frac=1)
df_cnn_test = pd.read_csv("test_noagesex.csv", header=None)

# %%
# Get data from dataframes
y_cnn = np.array(df_cnn_train[9].values).astype(np.int8)
y_cnn=to_categorical(y_cnn)
x_cnn = np.array(df_cnn_train[list(range(9))].values)[..., np.newaxis]
y_cnn_test = np.array(df_cnn_test[9].values).astype(np.int8)
x_cnn_test = np.array(df_cnn_test[list(range(9))].values)[..., np.newaxis]

# %% [markdown]
# # Model Definition + Training

# %%
# Model definition
def get_model(learning_rate=0.001):
    nclass = 2
    inp = Input(shape=(9, 1))
    
    cnn = Convolution1D(16, kernel_size=5, activation=activations.relu, padding="valid")(inp)
    cnn = Dropout(rate=0.1)(cnn) 
    cnn = Convolution1D(32, kernel_size=3, activation=activations.relu, padding="valid")(cnn)
    cnn = Dropout(rate=0.1)(cnn)
    cnn = Convolution1D(64, kernel_size=3, activation=activations.relu, padding="valid")(cnn)
    cnn = Dropout(rate=0.1)(cnn)
    cnn = Convolution1D(256, kernel_size=3, activation=activations.relu, padding="valid")(cnn)
    cnn = GlobalMaxPool1D()(cnn)
    cnn = Dropout(rate=0.1)(cnn)
    dense_1 = Dense(64, activation=activations.relu, name="dense_1", kernel_regularizer=regularizers.l2(l=0.1))(cnn)
    dense_1 = Dense(16, activation=activations.relu, name="dense_2", kernel_regularizer=regularizers.l2(l=0.1))(dense_1)
    dense_1 = Dense(nclass, activation=activations.softmax, name="dense_3_ecg_view")(dense_1) 
    

    model = models.Model(inputs=inp, outputs=dense_1)
    opt = optimizers.Adam(learning_rate)

    model.compile(optimizer=opt, loss=losses.binary_crossentropy, metrics=['acc'])
    return model

# %%
# Model Training
# Load model and model summary
model = get_model()
model.summary()

# File path to save the model
file_path = "cnn_ecgview_noagesex.h5"

# Checkpoint the model's weight based on the accuracy of the model
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# Set early stopping based on accuracy. It stops after 10 consecutive epochs of no accuracy improvement.
early = EarlyStopping(monitor="val_acc", mode="max", patience=10, verbose=1)

# Reduce learning rate based on accuracy. It reduces the rate after 7 consecutive epochs of no accuracy improvement.
redonplat = ReduceLROnPlateau(monitor="val_acc", mode="max", patience=7, verbose=2)

callbacks_list = [checkpoint, early, redonplat]

# Train the model, load weights into above file path to save the model
model.fit(x_cnn, y_cnn, epochs=1000, verbose=2, callbacks=callbacks_list, validation_split=0.1)
model.load_weights(file_path)

# The file will be saved in the file_path and can be loaded later using Keras for evaluation
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 9, 1)              0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 9, 16)             96
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 16)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 7, 32)             1568
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 32)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 5, 64)             6208
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 3, 256)            49408
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_3_ecg_view (Dense)     (None, 2)                 34
# =================================================================
# Total params: 74,802
# Trainable params: 74,802
# Non-trainable params: 0
# _________________________________________________________________
# Train on 380727 samples, validate on 42304 samples
# Epoch 1/1000
#  - 66s - loss: 0.5459 - acc: 0.7682 - val_loss: 0.4589 - val_acc: 0.7905
#
# Epoch 00001: val_acc improved from -inf to 0.79047, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 2/1000
#  - 68s - loss: 0.4590 - acc: 0.7848 - val_loss: 0.4344 - val_acc: 0.7980
#
# Epoch 00002: val_acc improved from 0.79047 to 0.79803, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 3/1000
#  - 58s - loss: 0.4471 - acc: 0.7903 - val_loss: 0.4248 - val_acc: 0.8042
#
# Epoch 00003: val_acc improved from 0.79803 to 0.80423, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 4/1000
#  - 59s - loss: 0.4401 - acc: 0.7932 - val_loss: 0.4183 - val_acc: 0.8032
#
# Epoch 00004: val_acc did not improve from 0.80423
# Epoch 5/1000
#  - 52s - loss: 0.4341 - acc: 0.7965 - val_loss: 0.4171 - val_acc: 0.8039
#
# Epoch 00005: val_acc did not improve from 0.80423
# Epoch 6/1000
#  - 60s - loss: 0.4292 - acc: 0.7986 - val_loss: 0.4058 - val_acc: 0.8112
#
# Epoch 00006: val_acc improved from 0.80423 to 0.81125, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 7/1000
#  - 61s - loss: 0.4250 - acc: 0.8001 - val_loss: 0.3983 - val_acc: 0.8131
#
# Epoch 00007: val_acc improved from 0.81125 to 0.81311, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 8/1000
#  - 52s - loss: 0.4219 - acc: 0.8013 - val_loss: 0.3953 - val_acc: 0.8159
#
# Epoch 00008: val_acc improved from 0.81311 to 0.81586, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 9/1000
#  - 64s - loss: 0.4182 - acc: 0.8028 - val_loss: 0.3893 - val_acc: 0.8168
#
# Epoch 00009: val_acc improved from 0.81586 to 0.81675, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 10/1000
#  - 53s - loss: 0.4157 - acc: 0.8034 - val_loss: 0.3971 - val_acc: 0.8134
#
# Epoch 00010: val_acc did not improve from 0.81675
# Epoch 11/1000
#  - 58s - loss: 0.4130 - acc: 0.8054 - val_loss: 0.3993 - val_acc: 0.8182
#
# Epoch 00011: val_acc improved from 0.81675 to 0.81817, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 12/1000
#  - 73s - loss: 0.4104 - acc: 0.8065 - val_loss: 0.3793 - val_acc: 0.8257
#
# Epoch 00012: val_acc improved from 0.81817 to 0.82569, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 13/1000
#  - 57s - loss: 0.4086 - acc: 0.8083 - val_loss: 0.3778 - val_acc: 0.8286
#
# Epoch 00013: val_acc improved from 0.82569 to 0.82862, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 14/1000
#  - 51s - loss: 0.4065 - acc: 0.8097 - val_loss: 0.3752 - val_acc: 0.8282
#
# Epoch 00014: val_acc did not improve from 0.82862
# Epoch 15/1000
#  - 50s - loss: 0.4047 - acc: 0.8104 - val_loss: 0.3794 - val_acc: 0.8271
#
# Epoch 00015: val_acc did not improve from 0.82862
# Epoch 16/1000
#  - 50s - loss: 0.4033 - acc: 0.8115 - val_loss: 0.3696 - val_acc: 0.8303
#
# Epoch 00016: val_acc improved from 0.82862 to 0.83032, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 17/1000
#  - 48s - loss: 0.4013 - acc: 0.8122 - val_loss: 0.3640 - val_acc: 0.8369
#
# Epoch 00017: val_acc improved from 0.83032 to 0.83689, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 18/1000
#  - 66s - loss: 0.3998 - acc: 0.8135 - val_loss: 0.3729 - val_acc: 0.8337
#
# Epoch 00018: val_acc did not improve from 0.83689
# Epoch 19/1000
#  - 55s - loss: 0.3985 - acc: 0.8132 - val_loss: 0.3596 - val_acc: 0.8347
#
# Epoch 00019: val_acc did not improve from 0.83689
# Epoch 20/1000
#  - 53s - loss: 0.3972 - acc: 0.8150 - val_loss: 0.3598 - val_acc: 0.8366
#
# Epoch 00020: val_acc did not improve from 0.83689
# Epoch 21/1000
#  - 54s - loss: 0.3964 - acc: 0.8153 - val_loss: 0.3555 - val_acc: 0.8397
#
# Epoch 00021: val_acc improved from 0.83689 to 0.83971, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 22/1000
#  - 58s - loss: 0.3948 - acc: 0.8167 - val_loss: 0.3570 - val_acc: 0.8418
#
# Epoch 00022: val_acc improved from 0.83971 to 0.84176, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 23/1000
#  - 63s - loss: 0.3938 - acc: 0.8172 - val_loss: 0.3570 - val_acc: 0.8416
#
# Epoch 00023: val_acc did not improve from 0.84176
# Epoch 24/1000
#  - 50s - loss: 0.3920 - acc: 0.8176 - val_loss: 0.3583 - val_acc: 0.8426
#
# Epoch 00024: val_acc improved from 0.84176 to 0.84262, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 25/1000
#  - 54s - loss: 0.3919 - acc: 0.8178 - val_loss: 0.3593 - val_acc: 0.8395
#
# Epoch 00025: val_acc did not improve from 0.84262
# Epoch 26/1000
#  - 52s - loss: 0.3912 - acc: 0.8182 - val_loss: 0.3828 - val_acc: 0.8309
#
# Epoch 00026: val_acc did not improve from 0.84262
# Epoch 27/1000
#  - 49s - loss: 0.3897 - acc: 0.8196 - val_loss: 0.3533 - val_acc: 0.8464
#
# Epoch 00027: val_acc improved from 0.84262 to 0.84635, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 28/1000
#  - 50s - loss: 0.3892 - acc: 0.8201 - val_loss: 0.3424 - val_acc: 0.8494
#
# Epoch 00028: val_acc improved from 0.84635 to 0.84942, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 29/1000
#  - 52s - loss: 0.3876 - acc: 0.8202 - val_loss: 0.3600 - val_acc: 0.8421
#
# Epoch 00029: val_acc did not improve from 0.84942
# Epoch 30/1000
#  - 52s - loss: 0.3868 - acc: 0.8217 - val_loss: 0.3484 - val_acc: 0.8467
#
# Epoch 00030: val_acc did not improve from 0.84942
# Epoch 31/1000
#  - 51s - loss: 0.3860 - acc: 0.8213 - val_loss: 0.3382 - val_acc: 0.8516
#
# Epoch 00031: val_acc improved from 0.84942 to 0.85155, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 32/1000
#  - 53s - loss: 0.3862 - acc: 0.8220 - val_loss: 0.3464 - val_acc: 0.8508
#
# Epoch 00032: val_acc did not improve from 0.85155
# Epoch 33/1000
#  - 58s - loss: 0.3845 - acc: 0.8231 - val_loss: 0.3383 - val_acc: 0.8519
#
# Epoch 00033: val_acc improved from 0.85155 to 0.85188, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 34/1000
#  - 51s - loss: 0.3848 - acc: 0.8229 - val_loss: 0.3422 - val_acc: 0.8518
#
# Epoch 00034: val_acc did not improve from 0.85188
# Epoch 35/1000
#  - 62s - loss: 0.3829 - acc: 0.8237 - val_loss: 0.3360 - val_acc: 0.8540
#
# Epoch 00035: val_acc improved from 0.85188 to 0.85403, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 36/1000
#  - 58s - loss: 0.3828 - acc: 0.8237 - val_loss: 0.3603 - val_acc: 0.8419
#
# Epoch 00036: val_acc did not improve from 0.85403
# Epoch 37/1000
#  - 52s - loss: 0.3820 - acc: 0.8245 - val_loss: 0.3366 - val_acc: 0.8543
# Epoch 00037: val_acc improved from 0.85403 to 0.85432, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 38/1000
#  - 48s - loss: 0.3816 - acc: 0.8245 - val_loss: 0.3388 - val_acc: 0.8543
#
# Epoch 00038: val_acc did not improve from 0.85432
# Epoch 39/1000
#  - 47s - loss: 0.3801 - acc: 0.8257 - val_loss: 0.3382 - val_acc: 0.8556
#
# Epoch 00039: val_acc improved from 0.85432 to 0.85562, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 40/1000
#  - 47s - loss: 0.3798 - acc: 0.8258 - val_loss: 0.3401 - val_acc: 0.8536
#
# Epoch 00040: val_acc did not improve from 0.85562
# Epoch 41/1000
#  - 47s - loss: 0.3808 - acc: 0.8249 - val_loss: 0.3385 - val_acc: 0.8548
#
# Epoch 00041: val_acc did not improve from 0.85562
# Epoch 42/1000
#  - 47s - loss: 0.3795 - acc: 0.8262 - val_loss: 0.3398 - val_acc: 0.8553
#
# Epoch 00042: val_acc did not improve from 0.85562
# Epoch 43/1000
#  - 48s - loss: 0.3781 - acc: 0.8270 - val_loss: 0.3227 - val_acc: 0.8609
#
# Epoch 00043: val_acc improved from 0.85562 to 0.86091, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 44/1000
#  - 47s - loss: 0.3781 - acc: 0.8262 - val_loss: 0.3282 - val_acc: 0.8592
#
# Epoch 00044: val_acc did not improve from 0.86091
# Epoch 45/1000
#  - 47s - loss: 0.3778 - acc: 0.8265 - val_loss: 0.3224 - val_acc: 0.8620
#
# Epoch 00045: val_acc improved from 0.86091 to 0.86195, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 46/1000
#  - 47s - loss: 0.3773 - acc: 0.8273 - val_loss: 0.3215 - val_acc: 0.8607
#
# Epoch 00046: val_acc did not improve from 0.86195
# Epoch 47/1000
#  - 47s - loss: 0.3764 - acc: 0.8276 - val_loss: 0.3226 - val_acc: 0.8617
#
# Epoch 00047: val_acc did not improve from 0.86195
# Epoch 48/1000
#  - 47s - loss: 0.3759 - acc: 0.8276 - val_loss: 0.3405 - val_acc: 0.8513
#
# Epoch 00048: val_acc did not improve from 0.86195
# Epoch 49/1000
#  - 47s - loss: 0.3752 - acc: 0.8281 - val_loss: 0.3304 - val_acc: 0.8612
#
# Epoch 00049: val_acc did not improve from 0.86195
# Epoch 50/1000
#  - 47s - loss: 0.3755 - acc: 0.8285 - val_loss: 0.3339 - val_acc: 0.8593
#
# Epoch 00050: val_acc did not improve from 0.86195
# Epoch 51/1000
#  - 47s - loss: 0.3746 - acc: 0.8286 - val_loss: 0.3258 - val_acc: 0.8611
#
# Epoch 00051: val_acc did not improve from 0.86195
# Epoch 52/1000
#  - 196s - loss: 0.3746 - acc: 0.8287 - val_loss: 0.3297 - val_acc: 0.8615
#
# Epoch 00052: val_acc did not improve from 0.86195
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 53/1000
#  - 63s - loss: 0.3624 - acc: 0.8343 - val_loss: 0.3163 - val_acc: 0.8655
#
# Epoch 00053: val_acc improved from 0.86195 to 0.86547, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 54/1000
#  - 58s - loss: 0.3590 - acc: 0.8360 - val_loss: 0.3106 - val_acc: 0.8682
#
# Epoch 00054: val_acc improved from 0.86547 to 0.86819, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 55/1000
#  - 59s - loss: 0.3585 - acc: 0.8360 - val_loss: 0.3109 - val_acc: 0.8681
#
# Epoch 00055: val_acc did not improve from 0.86819
# Epoch 56/1000
#  - 48s - loss: 0.3583 - acc: 0.8356 - val_loss: 0.3108 - val_acc: 0.8690
#
# Epoch 00056: val_acc improved from 0.86819 to 0.86902, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 57/1000
#  - 47s - loss: 0.3572 - acc: 0.8364 - val_loss: 0.3125 - val_acc: 0.8687
#
# Epoch 00057: val_acc did not improve from 0.86902
# Epoch 58/1000
#  - 48s - loss: 0.3570 - acc: 0.8368 - val_loss: 0.3127 - val_acc: 0.8667
#
# Epoch 00058: val_acc did not improve from 0.86902
# Epoch 59/1000
#  - 52s - loss: 0.3561 - acc: 0.8370 - val_loss: 0.3048 - val_acc: 0.8730
#
# Epoch 00059: val_acc improved from 0.86902 to 0.87299, saving model to baseline_cnn_ecgview_noagesex.h5
# Epoch 60/1000
#  - 51s - loss: 0.3559 - acc: 0.8373 - val_loss: 0.3116 - val_acc: 0.8683
#
# Epoch 00060: val_acc did not improve from 0.87299
# Epoch 61/1000
#  - 48s - loss: 0.3568 - acc: 0.8364 - val_loss: 0.3070 - val_acc: 0.8698
#
# Epoch 00061: val_acc did not improve from 0.87299
# Epoch 62/1000
#  - 47s - loss: 0.3568 - acc: 0.8365 - val_loss: 0.3059 - val_acc: 0.8711
#
# Epoch 00062: val_acc did not improve from 0.87299
# Epoch 63/1000
#  - 48s - loss: 0.3556 - acc: 0.8375 - val_loss: 0.3019 - val_acc: 0.8722
#
# Epoch 00063: val_acc did not improve from 0.87299
# Epoch 64/1000
#  - 48s - loss: 0.3556 - acc: 0.8373 - val_loss: 0.3095 - val_acc: 0.8690
#
# Epoch 00064: val_acc did not improve from 0.87299
# Epoch 65/1000
#  - 47s - loss: 0.3555 - acc: 0.8380 - val_loss: 0.3077 - val_acc: 0.8703
#
# Epoch 00065: val_acc did not improve from 0.87299
# Epoch 66/1000
#  - 48s - loss: 0.3550 - acc: 0.8372 - val_loss: 0.3050 - val_acc: 0.8708
#
# Epoch 00066: val_acc did not improve from 0.87299
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 67/1000
#  - 48s - loss: 0.3541 - acc: 0.8378 - val_loss: 0.3044 - val_acc: 0.8712
#
# Epoch 00067: val_acc did not improve from 0.87299
# Epoch 68/1000
#  - 48s - loss: 0.3536 - acc: 0.8381 - val_loss: 0.3057 - val_acc: 0.8707
#
# Epoch 00068: val_acc did not improve from 0.87299
# Epoch 69/1000
#  - -29s - loss: 0.3533 - acc: 0.8387 - val_loss: 0.3057 - val_acc: 0.8712
#
# Epoch 00069: val_acc did not improve from 0.87299
# Epoch 00069: early stopping
